# %% [markdown]
# # LLM Serving Reliability Demo
# Upload the zip, unzip it, and run the demo.

# %%
# !unzip -q -o llm-serving-reliability-demo.zip
# %cd llm-serving-reliability-demo

# %%
# !pip install -q -r requirements.txt

# %%
# !python main.py --workers 3 --requests 100 --failure_rate 0.08

# %%
# !cat metrics/results.json
